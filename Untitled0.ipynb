# %% [markdown]
# <a href="https://colab.research.google.com/github/QudsiaKhan/...-...-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q streamlit pyngrok cloudflared
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 2.2 MB/s eta 0:00:00
#   Building wheel for cloudflared (setup.py) ... done

# %% [markdown]
# I am a student of BS Computer Science (7th semester). In this semester I have a subject Artificial Intelligence and my teacher give me assignment
#  The assignment is
# Title: AI-Powered Requirements-to-Code Generator
# Problem: Software requirements rarely match final code.
# Solution: Build an app where user enters requirements → system generates: • UML diagrams • ERD • Initial code skeleton
# I want to create simple app that generates code in python, please consider the following points:
# 1.I will test my code in colab
# 2.I am a complete beginner so please give me step by step process
# 3.For frontend or UI use streamlit and use cloudflair to run the app
# 4.Use latest stable liberaries, dependencies, research documents and also consider to compatibility issue.

# %%
# %%writefile app.py

import streamlit as st
from graphviz import Digraph

# ---------- App Title ----------
st.title("🤖 AI-Powered Requirements-to-Code Generator")
st.write("Enter software requirements and generate UML, ERD, and Python code skeleton.")

# ---------- User Input ----------
requirements = st.text_area(
    "📌 Enter your software requirements:",
    placeholder="Example: I want a student management system with login, database, and course registration"
)

# ---------- AI Logic (Rule-Based NLP) ----------
def generate_output(req):
    req = req.lower()

    # UML Use Case
    use_cases = []
    if "login" in req:
        use_cases.append("User Login")
    if "register" in req:
        use_cases.append("User Registration")
    if "student" in req:
        use_cases.append("Manage Student")
    if "course" in req:
        use_cases.append("Manage Course")
    if "database" in req:
        use_cases.append("Store Data")

    # ERD Entities
    entities = []
    if "student" in req:
        entities.append("Student (id, name, email)")
    if "course" in req:
        entities.append("Course (course_id, title)")
    if "user" in req or "login" in req:
        entities.append("User (user_id, username, password)")

    # Python Code Skeleton
    code = """# Auto-generated Python Code Skeleton

class User:
    def login(self):
        pass

class Student:
    def add_student(self):
        pass

class Course:
    def add_course(self):
        pass
"""

    return use_cases, entities, code

# ---------- Diagram Generators ----------
def draw_use_case_diagram(use_cases):
    dot = Digraph(comment='Use Case Diagram', format='png')
    dot.attr('node', shape='ellipse', style='filled', color='lightblue')

    dot.node('Actor', 'User')

    for uc in use_cases:
        dot.node(uc)
        dot.edge('Actor', uc)

    return dot

def draw_erd(entities):
    dot = Digraph(comment='ER Diagram', format='png')
    dot.attr('node', shape='record', style='filled', color='lightyellow')

    for e in entities:
        # Split entity name and attributes
        name_attr = e.split('(')
        entity_name = name_attr[0].strip()
        attrs = name_attr[1].replace(')', '').strip() if len(name_attr) > 1 else ''
        dot.node(entity_name, f"{{{entity_name}|{attrs}}}")

    return dot

# ---------- Button ----------
if st.button("🚀 Generate Output"):
    if requirements.strip() == "":
        st.warning("Please enter some requirements first.")
    else:
        use_cases, entities, code = generate_output(requirements)

        # Graphical Use Case
        st.subheader("📊 UML Use Case Diagram (Graphical)")
        uc_dot = draw_use_case_diagram(use_cases)
        st.graphviz_chart(uc_dot)

        # Graphical ERD
        st.subheader("🗄 ER Diagram (Graphical)")
        er_dot = draw_erd(entities)
        st.graphviz_chart(er_dot)

        # Python Code Skeleton
        st.subheader("💻 Python Code Skeleton")
        st.code(code, language="python")
# Out:
# Writing app.py

# %%
# !npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 1 package in 3s
# ⠙

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !cloudflared tunnel --url http://localhost:8501
# Out:
# 2025-12-17T09:24:34Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2025-12-17T09:24:34Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2025-12-17T09:24:37Z INF +--------------------------------------------------------------------------------------------+
# 2025-12-17T09:24:37Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2025-12-17T09:24:37Z INF |  https://waterproof-new-matt-dramatically.trycloudflare.com                                |
# 2025-12-17T09:24:37Z INF +--------------------------------------------------------------------------------------------+
# 2025-12-17T09:24:37Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2025-12-17T09:24:37Z INF Version 2025.11.1 (Checksum 991dffd8889ee9f0147b6b48933da9e4407e68ea8c6d984f55fa2d3db4bb431d)
# 2025-12-17T09:24:37Z INF GOOS: linux, GOVersion: go1.24.9, GoArch: amd64
# 2025-12-17T09:24:37Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2025-12-17T09:24:37Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2025-12-17T09:24:37Z INF Generated Connector ID: 867f61b1-d9c3-4a44-ae7a-c0847872a9aa
# 2025-12-17T09:24:37Z INF Initial protocol quic
# 2025-12-17T09:24:37Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2025-12-17T09:24:37Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2025-12-17T09:24:37Z ERR Cannot determine default origin certificate path. No file cert.pem in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]. You need to specify the origin certificate path by specifying the origincert option in the configuration file, or set TUNNEL_ORIGIN_CERT environment variable originCertPath=
# 2025-12-17T09:24:37Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2025-12-17T09:24:37Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2025-12-17T09:24:37Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2025-12-17T09:24:37Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.67
# 2025/12/17 09:24:37 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2025-12-17T09:24:37Z INF Registered tunnel connection connIndex=0 connection=4a9526e8-1737-4ac0-babc-091de2dd6909 event=0 ip=198.41.192.67 location=sea01 protocol=quic
